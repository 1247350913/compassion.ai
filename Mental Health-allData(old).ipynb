# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

# %%
mental_2014 = pd.read_csv('data/mental_2014.csv')
mental_2014.head()
# Out:
#              Timestamp  Age  Gender         Country state self_employed  \
# 0  2014-08-27 11:29:31   37  Female   United States    IL           NaN
# 1  2014-08-27 11:29:37   44       M   United States    IN           NaN
# 2  2014-08-27 11:29:44   32    Male          Canada   NaN           NaN
# 3  2014-08-27 11:29:46   31    Male  United Kingdom   NaN           NaN
# 4  2014-08-27 11:30:22   31    Male   United States    TX           NaN
#
#   family_history treatment work_interfere    no_employees  ...  \
# 0             No       Yes          Often            6-25  ...
# 1             No        No         Rarely  More than 1000  ...
# 2             No        No         Rarely            6-25  ...
# 3            Yes       Yes          Often          26-100  ...
# 4             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
#
#   mental_vs_physical obs_consequence comments
# 0                Yes              No      NaN
# 1         Don't know              No      NaN
# 2                 No              No      NaN
# 3                 No             Yes      NaN
# 4         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Data Cleaning

# %%
# Dropping unneeded columns

mental_2014 = mental_2014.drop(labels=['Timestamp', 'Country', 'state', 'self_employed', 'obs_consequence', 'comments', 'phys_health_consequence', 'phys_health_interview', 'work_interfere', 'mental_health_interview'], axis=1)
mental_2014.shape
# Out:
# (1259, 17)

# %%
mental_2014.head()
# Out:
#    Age  Gender family_history treatment    no_employees remote_work  \
# 0   37  Female             No       Yes            6-25          No
# 1   44       M             No        No  More than 1000          No
# 2   32    Male             No        No            6-25          No
# 3   31    Male            Yes       Yes          26-100          No
# 4   31    Male             No        No         100-500         Yes
#
#   tech_company    benefits care_options wellness_program   seek_help  \
# 0          Yes         Yes     Not sure               No         Yes
# 1           No  Don't know           No       Don't know  Don't know
# 2          Yes          No           No               No          No
# 3          Yes          No          Yes               No          No
# 4          Yes         Yes           No       Don't know  Don't know
#
#     anonymity               leave mental_health_consequence     coworkers  \
# 0         Yes       Somewhat easy                        No  Some of them
# 1  Don't know          Don't know                     Maybe            No
# 2  Don't know  Somewhat difficult                        No           Yes
# 3          No  Somewhat difficult                       Yes  Some of them
# 4  Don't know          Don't know                        No  Some of them
#
#   supervisor mental_vs_physical
# 0        Yes                Yes
# 1         No         Don't know
# 2        Yes                 No
# 3         No                 No
# 4        Yes         Don't know

# %%
mental_2016 = pd.read_csv('data/mental_2016.csv')
mental_2016.head()
# Out:
#    Age  Gender family_history  treatment no_employees remote_work  \
# 0   39    Male             No          0       26-100   Sometimes
# 1   29    male            Yes          1         6-25       Never
# 2   38   Male              No          1         6-25      Always
# 3   43    male             No          1          NaN   Sometimes
# 4   43  Female            Yes          1         6-25   Sometimes
#
#    tech_company                         benefits care_options  \
# 0           1.0  Not eligible for coverage / N/A          NaN
# 1           1.0                               No          Yes
# 2           1.0                               No          NaN
# 3           NaN                              NaN          NaN
# 4           0.0                              Yes          Yes
#
#   wellness_program seek_help     anonymity                       leave  \
# 0               No        No  I don't know                   Very easy
# 1              Yes       Yes           Yes               Somewhat easy
# 2               No        No  I don't know  Neither easy nor difficult
# 3              NaN       NaN           NaN                         NaN
# 4               No        No            No  Neither easy nor difficult
#
#   mental_health_consequence coworkers supervisor mental_vs_physical
# 0                        No     Maybe        Yes       I don't know
# 1                        No     Maybe        Yes                Yes
# 2                     Maybe     Maybe      Maybe       I don't know
# 3                       NaN       NaN        NaN                NaN
# 4                       Yes     Maybe         No                 No

# %%
mental_2016.shape
# Out:
# (1433, 17)

# %%
mental_2019 = pd.read_csv('data/mental_2019.csv')
mental_2019.head()
# Out:
#    Age family_history  treatment no_employees tech_company      benefits  \
# 0   25             No      False       26-100         True  I don't know
# 1   51            Yes      False       26-100         True           Yes
# 2   27   I don't know      False       26-100         True  I don't know
# 3   37            Yes      False      100-500         True  I don't know
# 4   46             No      False       26-100         True  I don't know
#
#   care_options wellness_program     seek_help     anonymity  \
# 0           No              Yes           Yes  I don't know
# 1           No               No           Yes           Yes
# 2           No               No  I don't know  I don't know
# 3           No              Yes           Yes           Yes
# 4           No     I don't know  I don't know  I don't know
#
#                 leave mental_health_consequence coworkers supervisor  \
# 0           Very easy                        No       Yes        Yes
# 1        I don't know                        No     Maybe      Maybe
# 2  Somewhat difficult                        No     Maybe         No
# 3           Very easy                        No     Maybe        Yes
# 4        I don't know                       NaN        No         No
#
#    Overall, how much importance does your employer place on physical health?  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                1.0
# 4                                                4.0
#
#    Overall, how much importance does your employer place on mental health?
# 0                                                5.0
# 1                                                7.0
# 2                                                4.0
# 3                                                3.0
# 4                                                4.0

# %%
mental_2019['treatment'] = mental_2019['treatment'].astype(int)
mental_2019.head()
# Out:
#    Age family_history  treatment no_employees tech_company      benefits  \
# 0   25             No          0       26-100         True  I don't know
# 1   51            Yes          0       26-100         True           Yes
# 2   27   I don't know          0       26-100         True  I don't know
# 3   37            Yes          0      100-500         True  I don't know
# 4   46             No          0       26-100         True  I don't know
#
#   care_options wellness_program     seek_help     anonymity  \
# 0           No              Yes           Yes  I don't know
# 1           No               No           Yes           Yes
# 2           No               No  I don't know  I don't know
# 3           No              Yes           Yes           Yes
# 4           No     I don't know  I don't know  I don't know
#
#                 leave mental_health_consequence coworkers supervisor  \
# 0           Very easy                        No       Yes        Yes
# 1        I don't know                        No     Maybe      Maybe
# 2  Somewhat difficult                        No     Maybe         No
# 3           Very easy                        No     Maybe        Yes
# 4        I don't know                       NaN        No         No
#
#    Overall, how much importance does your employer place on physical health?  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                1.0
# 4                                                4.0
#
#    Overall, how much importance does your employer place on mental health?
# 0                                                5.0
# 1                                                7.0
# 2                                                4.0
# 3                                                3.0
# 4                                                4.0

# %%
mental_2019['tech_company'].fillna(value=False, inplace=True)
mental_2019['tech_company'] = mental_2019['tech_company'].astype(int)
mental_2019.head()
# Out:
#    Age family_history  treatment no_employees  tech_company      benefits  \
# 0   25             No          0       26-100             1  I don't know
# 1   51            Yes          0       26-100             1           Yes
# 2   27   I don't know          0       26-100             1  I don't know
# 3   37            Yes          0      100-500             1  I don't know
# 4   46             No          0       26-100             1  I don't know
#
#   care_options wellness_program     seek_help     anonymity  \
# 0           No              Yes           Yes  I don't know
# 1           No               No           Yes           Yes
# 2           No               No  I don't know  I don't know
# 3           No              Yes           Yes           Yes
# 4           No     I don't know  I don't know  I don't know
#
#                 leave mental_health_consequence coworkers supervisor  \
# 0           Very easy                        No       Yes        Yes
# 1        I don't know                        No     Maybe      Maybe
# 2  Somewhat difficult                        No     Maybe         No
# 3           Very easy                        No     Maybe        Yes
# 4        I don't know                       NaN        No         No
#
#    Overall, how much importance does your employer place on physical health?  \
# 0                                                5.0
# 1                                                5.0
# 2                                                5.0
# 3                                                1.0
# 4                                                4.0
#
#    Overall, how much importance does your employer place on mental health?
# 0                                                5.0
# 1                                                7.0
# 2                                                4.0
# 3                                                3.0
# 4                                                4.0

# %%
mental_2019['mental_vs_physical'] = mental_2019['Overall, how much importance does your employer place on physical health?'] < mental_2019['Overall, how much importance does your employer place on mental health?']
mental_2019.drop(columns=['Overall, how much importance does your employer place on physical health?', 'Overall, how much importance does your employer place on mental health?'], inplace=True)
mental_2019.head()
# Out:
#    Age family_history  treatment no_employees  tech_company      benefits  \
# 0   25             No          0       26-100             1  I don't know
# 1   51            Yes          0       26-100             1           Yes
# 2   27   I don't know          0       26-100             1  I don't know
# 3   37            Yes          0      100-500             1  I don't know
# 4   46             No          0       26-100             1  I don't know
#
#   care_options wellness_program     seek_help     anonymity  \
# 0           No              Yes           Yes  I don't know
# 1           No               No           Yes           Yes
# 2           No               No  I don't know  I don't know
# 3           No              Yes           Yes           Yes
# 4           No     I don't know  I don't know  I don't know
#
#                 leave mental_health_consequence coworkers supervisor  \
# 0           Very easy                        No       Yes        Yes
# 1        I don't know                        No     Maybe      Maybe
# 2  Somewhat difficult                        No     Maybe         No
# 3           Very easy                        No     Maybe        Yes
# 4        I don't know                       NaN        No         No
#
#    mental_vs_physical
# 0               False
# 1                True
# 2               False
# 3                True
# 4               False

# %%
mental_2019['mental_vs_physical'] = mental_2019['mental_vs_physical'].replace({True:'Yes', False:'No'})
mental_2019.head()
# Out:
#    Age family_history  treatment no_employees  tech_company      benefits  \
# 0   25             No          0       26-100             1  I don't know
# 1   51            Yes          0       26-100             1           Yes
# 2   27   I don't know          0       26-100             1  I don't know
# 3   37            Yes          0      100-500             1  I don't know
# 4   46             No          0       26-100             1  I don't know
#
#   care_options wellness_program     seek_help     anonymity  \
# 0           No              Yes           Yes  I don't know
# 1           No               No           Yes           Yes
# 2           No               No  I don't know  I don't know
# 3           No              Yes           Yes           Yes
# 4           No     I don't know  I don't know  I don't know
#
#                 leave mental_health_consequence coworkers supervisor  \
# 0           Very easy                        No       Yes        Yes
# 1        I don't know                        No     Maybe      Maybe
# 2  Somewhat difficult                        No     Maybe         No
# 3           Very easy                        No     Maybe        Yes
# 4        I don't know                       NaN        No         No
#
#   mental_vs_physical
# 0                 No
# 1                Yes
# 2                 No
# 3                Yes
# 4                 No

# %%
mental_2016['supervisor'].unique()
# Out:
# array(['Yes', 'Maybe', nan, 'No'], dtype=object)

# %%
mental_2019['supervisor'].unique()
# Out:
# array(['Yes', 'Maybe', 'No', nan], dtype=object)

# %%
# Combining the two datasets

combined = pd.concat([mental_2014, mental_2016, mental_2019], axis=0)
combined.head()
# Out:
#    Age  Gender family_history treatment    no_employees remote_work  \
# 0   37  Female             No       Yes            6-25          No
# 1   44       M             No        No  More than 1000          No
# 2   32    Male             No        No            6-25          No
# 3   31    Male            Yes       Yes          26-100          No
# 4   31    Male             No        No         100-500         Yes
#
#   tech_company    benefits care_options wellness_program   seek_help  \
# 0          Yes         Yes     Not sure               No         Yes
# 1           No  Don't know           No       Don't know  Don't know
# 2          Yes          No           No               No          No
# 3          Yes          No          Yes               No          No
# 4          Yes         Yes           No       Don't know  Don't know
#
#     anonymity               leave mental_health_consequence     coworkers  \
# 0         Yes       Somewhat easy                        No  Some of them
# 1  Don't know          Don't know                     Maybe            No
# 2  Don't know  Somewhat difficult                        No           Yes
# 3          No  Somewhat difficult                       Yes  Some of them
# 4  Don't know          Don't know                        No  Some of them
#
#   supervisor mental_vs_physical
# 0        Yes                Yes
# 1         No         Don't know
# 2        Yes                 No
# 3         No                 No
# 4        Yes         Don't know

# %%
# Removing 'Maybe' responses

responses = ['Yes', 'No']
combined = combined[combined['mental_vs_physical'].str.contains('|'.join(responses)) == True]

# %%
combined.shape
# Out:
# (1688, 17)

# %%
combined.head()
# Out:
#    Age  Gender family_history treatment no_employees remote_work tech_company  \
# 0   37  Female             No       Yes         6-25          No          Yes
# 2   32    Male             No        No         6-25          No          Yes
# 3   31    Male            Yes       Yes       26-100          No          Yes
# 7   39       M             No        No          1-5         Yes          Yes
# 8   42  Female            Yes       Yes      100-500          No          Yes
#
#   benefits care_options wellness_program seek_help   anonymity  \
# 0      Yes     Not sure               No       Yes         Yes
# 2       No           No               No        No  Don't know
# 3       No          Yes               No        No          No
# 7       No          Yes               No        No         Yes
# 8      Yes          Yes               No        No          No
#
#                 leave mental_health_consequence     coworkers supervisor  \
# 0       Somewhat easy                        No  Some of them        Yes
# 2  Somewhat difficult                        No           Yes        Yes
# 3  Somewhat difficult                       Yes  Some of them         No
# 7          Don't know                        No            No         No
# 8      Very difficult                     Maybe           Yes        Yes
#
#   mental_vs_physical
# 0                Yes
# 2                 No
# 3                 No
# 7                 No
# 8                 No

# %%
# Fixing null values in 'care_options'

combined['care_options'] = combined['care_options'].str.replace('I am not sure', 'Not sure')
combined['care_options'].unique()
# Out:
# array(['Not sure', 'No', 'Yes', nan], dtype=object)

# %%
combined['care_options'].fillna(value='Not sure', inplace=True)
combined['care_options'].isna().sum()
# Out:
# 0

# %%
combined.drop(columns=['Gender', 'remote_work'], inplace=True)
combined.rename(columns={'Age':'age'}, inplace=True)

# %%
combined.shape
# Out:
# (1688, 15)

# %%
combined.dropna(how='any').shape
# Out:
# (1581, 15)

# %%
combined.head()
# Out:
#    age family_history treatment no_employees tech_company benefits  \
# 0   37             No       Yes         6-25          Yes      Yes
# 2   32             No        No         6-25          Yes       No
# 3   31            Yes       Yes       26-100          Yes       No
# 7   39             No        No          1-5          Yes       No
# 8   42            Yes       Yes      100-500          Yes      Yes
#
#   care_options wellness_program seek_help   anonymity               leave  \
# 0     Not sure               No       Yes         Yes       Somewhat easy
# 2           No               No        No  Don't know  Somewhat difficult
# 3          Yes               No        No          No  Somewhat difficult
# 7          Yes               No        No         Yes          Don't know
# 8          Yes               No        No          No      Very difficult
#
#   mental_health_consequence     coworkers supervisor mental_vs_physical
# 0                        No  Some of them        Yes                Yes
# 2                        No           Yes        Yes                 No
# 3                       Yes  Some of them         No                 No
# 7                        No            No         No                 No
# 8                     Maybe           Yes        Yes                 No

# %%
count = 0
for column in combined.columns[1:]:
    count += len(combined[column].unique())
    print(combined[column].unique())
print(count)
# Out:
# ['No' 'Yes' "I don't know"]
# ['Yes' 'No' 1 0]
# ['6-25' '26-100' '1-5' '100-500' 'More than 1000' '500-1000' nan]
# ['Yes' 'No' 1.0 0.0]
# ['Yes' 'No' "Don't know" "I don't know" 'Not eligible for coverage / N/A'
#  nan 'Not eligible for coverage / NA']
# ['Not sure' 'No' 'Yes']
# ['No' "Don't know" 'Yes' "I don't know" nan]
# ['Yes' 'No' "Don't know" "I don't know" nan]
# ['Yes' "Don't know" 'No' "I don't know" nan]
# ['Somewhat easy' 'Somewhat difficult' "Don't know" 'Very difficult'
#  'Very easy' 'Neither easy nor difficult' "I don't know" nan 'Difficult']
# ['No' 'Yes' 'Maybe' nan]
# ['Some of them' 'Yes' 'No' 'Maybe' nan]
# ['Yes' 'No' 'Some of them' 'Maybe' nan]
# ['Yes' 'No']
# 68

# %% [markdown]
# ## Model Building

# %%
from sklearn.model_selection import train_test_split

# split into train and test sets and dummy encode

X = pd.get_dummies(combined.drop(['mental_vs_physical'], axis=1))
y = [1 if i == 'Yes' else 0 for i in combined['mental_vs_physical']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=88)

train = X_train.copy()
train['mental_vs_physical'] = y_train

test = X_test.copy()
test['mental-vs_physical'] = y_test

X_train.shape, X_test.shape
# Out:
# ((1350, 58), (338, 58))

# %%
def TPR(y_test, y_pred):
    cm = confusion_matrix(y_test, y_pred)
    return cm.ravel()[3]/ (cm.ravel()[3] + cm.ravel()[2])
def FPR(y_test, y_pred):
    cm = confusion_matrix(y_test, y_pred)
    return cm.ravel()[1]/ (cm.ravel()[1] + cm.ravel()[0])

# %% [markdown]
# ### Baseline

# %%
plt.pie([75, 25])
# Out:
# ([<matplotlib.patches.Wedge at 0x1329d0518>,
#   <matplotlib.patches.Wedge at 0x1329d09e8>],
#  [Text(-0.7778174593052023, 0.7778174593052024, ''),
#   Text(0.7778174593052023, -0.7778174593052025, '')])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
print('1:',np.count_nonzero(y_test))
print('0:',len(y_test) - np.count_nonzero(y_test))
# Out:
# 1: 145
# 0: 193

# %%
# Baseline always predicts 0
y_pred_baseline = np.zeros(len(y_test))
print('Baseline ACC:', accuracy_score(y_test, y_pred_baseline))
print('Baseline TPR:', TPR(y_test, y_pred_baseline))
print('Baseline FPR:', FPR(y_test, y_pred_baseline))
# Out:
# Baseline ACC: 0.5710059171597633
# Baseline TPR: 0.0
# Baseline FPR: 0.0

# %% [markdown]
# ### Logistic Regression

# %%
# fit logistic regression model
logreg = LogisticRegression(random_state=88)
logreg.fit(X_train, y_train)

y_prob = logreg.predict_proba(X_test)
y_pred_logreg = pd.Series([1 if x > 0.5 else 0 for x in y_prob[:,1]])

cm_logreg = confusion_matrix(y_test, y_pred_logreg)
print ("Confusion Matrix: \n", cm_logreg)
print ("Accuracy:", accuracy_score(y_test, y_pred_logreg))
print ("TPR:", TPR(y_test, y_pred_logreg))
print ("FPR:", FPR(y_test, y_pred_logreg))
# Out:
# Confusion Matrix:
#  [[164  29]
#  [ 35 110]]
# Accuracy: 0.8106508875739645
# TPR: 0.7586206896551724
# FPR: 0.15025906735751296
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/linear_model/_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# first try grid search for best ccp_alpha
grid_values = {'ccp_alpha': np.linspace(0, 0.1, 51)}

dtc = DecisionTreeClassifier(random_state=88)
dtc_cv = GridSearchCV(dtc, param_grid=grid_values, cv=5).fit(X_train, y_train)

# %%
# plot ccp_alpha values from grid search first try
ccp_alpha = dtc_cv.cv_results_['param_ccp_alpha'].data
ACC_scores = dtc_cv.cv_results_['mean_test_score']

plt.figure(figsize=(8, 6))
plt.xlabel('ccp_alpha', fontsize=16)
plt.ylabel('CV Accuracy', fontsize=16)
plt.scatter(ccp_alpha, ACC_scores, s=3)
plt.plot(ccp_alpha, ACC_scores, linewidth=3)
plt.grid(True, which='both')

plt.tight_layout()
plt.show()

print('Best ccp_alpha', dtc_cv.best_params_)
# Out:
# Best ccp_alpha {'ccp_alpha': 0.006}

# %%
# second try grid search for best ccp_alpha
grid_values = {'ccp_alpha': np.linspace(0, 0.01, 101)}

dtc = DecisionTreeClassifier(random_state=88)
dtc_cv = GridSearchCV(dtc, param_grid=grid_values, cv=5).fit(X_train, y_train)

# %%
# plot ccp_alpha values from grid search second try
ccp_alpha = dtc_cv.cv_results_['param_ccp_alpha'].data
ACC_scores = dtc_cv.cv_results_['mean_test_score']

plt.figure(figsize=(8, 6))
plt.xlabel('ccp_alpha', fontsize=16)
plt.ylabel('CV Accuracy', fontsize=16)
plt.scatter(ccp_alpha, ACC_scores, s=3)
plt.plot(ccp_alpha, ACC_scores, linewidth=3)
plt.grid(True, which='both')

plt.tight_layout()
plt.show()

print('Best ccp_alpha', dtc_cv.best_params_)
# Out:
# Best ccp_alpha {'ccp_alpha': 0.0048000000000000004}

# %%
y_pred_dtc = dtc_cv.predict(X_test)
cm_dtc = confusion_matrix(y_test, y_pred_dtc)
print ("Confusion Matrix: \n", cm_dtc)
print ("Accuracy:", accuracy_score(y_test, y_pred_dtc))
print ("TPR:", TPR(y_test, y_pred_dtc))
print ("FPR:", FPR(y_test, y_pred_dtc))
# Out:
# Confusion Matrix:
#  [[160  33]
#  [ 32 113]]
# Accuracy: 0.8076923076923077
# TPR: 0.7793103448275862
# FPR: 0.17098445595854922

# %% [markdown]
# ### Vanilla Bagging

# %%
from sklearn.ensemble import RandomForestClassifier

# random forest model with max_features set to the total number of features 

bagging = RandomForestClassifier(max_features=len(X_train.columns), random_state=1)
bagging.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features=58, random_state=1)

# %%
y_pred_bagging = bagging.predict(X_test)
cm_bagging = confusion_matrix(y_test, y_pred_bagging)
print ("Confusion Matrix: \n", cm_bagging)
print ("Accuracy:", accuracy_score(y_test, y_pred_bagging))
print ("TPR:", TPR(y_test, y_pred_bagging))
print ("FPR:", FPR(y_test, y_pred_bagging))
# Out:
# Confusion Matrix:
#  [[163  30]
#  [ 36 109]]
# Accuracy: 0.8047337278106509
# TPR: 0.7517241379310344
# FPR: 0.15544041450777202

# %% [markdown]
# ### Random Forest

# %%
combined.head(1)
# Out:
#    age family_history treatment no_employees tech_company benefits  \
# 0   37             No       Yes         6-25          Yes      Yes
#
#   care_options wellness_program seek_help anonymity          leave  \
# 0     Not sure               No       Yes       Yes  Somewhat easy
#
#   mental_health_consequence     coworkers supervisor mental_vs_physical
# 0                        No  Some of them        Yes                Yes

# %%
X.head(1)
# Out:
#    age  family_history_I don't know  family_history_No  family_history_Yes  \
# 0   37                            0                  1                   0
#
#    treatment_0  treatment_1  treatment_No  treatment_Yes  no_employees_1-5  \
# 0            0            0             0              1                 0
#
#    no_employees_100-500  ...  mental_health_consequence_No  \
# 0                     0  ...                             1
#
#    mental_health_consequence_Yes  coworkers_Maybe  coworkers_No  \
# 0                              0                0             0
#
#    coworkers_Some of them  coworkers_Yes  supervisor_Maybe  supervisor_No  \
# 0                       1              0                 0              0
#
#    supervisor_Some of them  supervisor_Yes
# 0                        0               1
#
# [1 rows x 58 columns]

# %%
X_test.head(1)
# Out:
#      age  family_history_I don't know  family_history_No  family_history_Yes  \
# 342   26                            0                  1                   0
#
#      treatment_0  treatment_1  treatment_No  treatment_Yes  no_employees_1-5  \
# 342            1            0             0              0                 0
#
#      no_employees_100-500  ...  mental_health_consequence_No  \
# 342                     0  ...                             1
#
#      mental_health_consequence_Yes  coworkers_Maybe  coworkers_No  \
# 342                              0                0             0
#
#      coworkers_Some of them  coworkers_Yes  supervisor_Maybe  supervisor_No  \
# 342                       0              1                 0              0
#
#      supervisor_Some of them  supervisor_Yes
# 342                        0               1
#
# [1 rows x 58 columns]

# %%
# grid search for max_features
grid_values = {'max_features': np.linspace(1,8,8, dtype='int32'),
               'min_samples_leaf': [5],
               'n_estimators': [500],
               'random_state': [88]} 

rf = RandomForestClassifier() 
rf_cv = GridSearchCV(rf, param_grid=grid_values, cv=5, verbose=1)
rf_cv.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:  1.6min finished
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'max_features': array([1, 2, 3, 4, 5, 6, 7, 8], dtype=int32),
#                          'min_samples_leaf': [5], 'n_estimators': [500],
#                          'random_state': [88]},
#              verbose=1)

# %%
combined.reset_index().head(1)
# Out:
#    index  age family_history treatment no_employees tech_company benefits  \
# 0      0   37             No       Yes         6-25          Yes      Yes
#
#   care_options wellness_program seek_help anonymity          leave  \
# 0     Not sure               No       Yes       Yes  Somewhat easy
#
#   mental_health_consequence     coworkers supervisor mental_vs_physical
# 0                        No  Some of them        Yes                Yes

# %%
vals = combined.reset_index().loc[0].values
df = pd.DataFrame(columns=['index', 'age', 'family_history', 'treatment', 'no_employees', 'tech_company', 'benefits', 'care_options', 'wellness_program', 'seek_help', 'anonymity', 'leave', 'mental_health_consequence', 'coworkers', 'supervisor', 'mental_vs_physical'])
df.loc[len(df.index)] = vals
df
# Out:
#   index age family_history treatment no_employees tech_company benefits  \
# 0     0  37             No       Yes         6-25          Yes      Yes
#
#   care_options wellness_program seek_help anonymity          leave  \
# 0     Not sure               No       Yes       Yes  Somewhat easy
#
#   mental_health_consequence     coworkers supervisor mental_vs_physical
# 0                        No  Some of them        Yes                Yes

# %%
y_pred_rf = rf_cv.predict(X_test)
cm_rf = confusion_matrix(y_test, y_pred_rf)
print ("Confusion Matrix: \n", cm_rf)
print ("Accuracy:", accuracy_score(y_test, y_pred_rf))
print ("TPR:", TPR(y_test, y_pred_rf))
print ("FPR:", FPR(y_test, y_pred_rf))
# Out:
# Confusion Matrix:
#  [[171  22]
#  [ 40 105]]
# Accuracy: 0.8165680473372781
# TPR: 0.7241379310344828
# FPR: 0.11398963730569948

# %% [markdown]
# ### Linear SVM

# %%
from sklearn.svm import SVC, LinearSVC
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# grid search for C

grid_values = {'C': np.logspace(-2,2,10),
               'penalty': ['l2'],
               'loss': ['hinge']} 

tic = time.time()

svm = LinearSVC() 
scaler = StandardScaler()
scaled_x = scaler.fit_transform(X_train, y_train)
svm_cv = GridSearchCV(svm, param_grid=grid_values, cv=5, verbose=1)
svm_cv.fit(scaled_x, y_train)

toc = time.time()

print('time:', round(toc-tic, 2),'s')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:   18.0s finished
# time: 18.97 s
# /opt/anaconda3/lib/python3.8/site-packages/sklearn/svm/_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
y_pred_svm = svm_cv.predict(X_test)
cm_rf = confusion_matrix(y_test, y_pred_svm)
print ("Confusion Matrix: \n", cm_rf)
print ("Accuracy:", accuracy_score(y_test, y_pred_svm))
print ("TPR:", TPR(y_test, y_pred_svm))
print ("FPR:", FPR(y_test, y_pred_svm))
# Out:
# Confusion Matrix:
#  [[  5 188]
#  [  0 145]]
# Accuracy: 0.4437869822485207
# TPR: 1.0
# FPR: 0.9740932642487047

# %% [markdown]
# ### RBF SVM

# %%
# grid search for C, gamma

grid_values = {'C': np.logspace(-2,2,10),
               'gamma': np.logspace(-9, 3, 13),
                'kernel': ['rbf']} 

tic = time.time()

svm_rbf = SVC() 
scaler = StandardScaler()
scaled_x = scaler.fit_transform(X_train, y_train)
svm_cv_rbf = GridSearchCV(svm_rbf, param_grid=grid_values, cv=5, verbose=1)
svm_cv_rbf.fit(scaled_x, y_train)

toc = time.time()

print('time:', round(toc-tic, 2),'s')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 5 folds for each of 130 candidates, totalling 650 fits
# time: 152.01 s
# [Parallel(n_jobs=1)]: Done 650 out of 650 | elapsed:  2.5min finished

# %%
y_pred_svm_rbf = svm_cv_rbf.predict(X_test)
cm_rf = confusion_matrix(y_test, y_pred_svm_rbf)
print ("Confusion Matrix: \n", cm_rf)
print ("Accuracy:", accuracy_score(y_test, y_pred_svm_rbf))
print ("TPR:", TPR(y_test, y_pred_svm_rbf))
print ("FPR:", FPR(y_test, y_pred_svm_rbf))
# Out:
# Confusion Matrix:
#  [[193   0]
#  [144   1]]
# Accuracy: 0.5739644970414202
# TPR: 0.006896551724137931
# FPR: 0.0

# %% [markdown]
# ### Polynomial SVM

# %% [markdown]
# ## Evaluate Models

# %%
# table to evaluate performance of models
comparison_data = {'Baseline': [accuracy_score(y_test, y_pred_baseline), 
                                           TPR(y_test, y_pred_baseline), FPR(y_test, y_pred_baseline)],
                    'Logistic Regression': [accuracy_score(y_test, y_pred_logreg), 
                                           TPR(y_test, y_pred_logreg), FPR(y_test, y_pred_logreg)],
                   'Decision Tree': [accuracy_score(y_test, y_pred_dtc), TPR(y_test, y_pred_dtc), 
                                     FPR(y_test, y_pred_dtc)], 
                   'Vanilla Bagging': [accuracy_score(y_test, y_pred_bagging), TPR(y_test, y_pred_bagging), 
                                     FPR(y_test, y_pred_bagging)], 
                   'Random Forest': [accuracy_score(y_test, y_pred_rf), TPR(y_test, y_pred_rf), FPR(y_test, y_pred_rf)],
                   'Linear SVM': [accuracy_score(y_test, y_pred_svm), TPR(y_test, y_pred_svm), FPR(y_test, y_pred_svm)],
                    'RBF SVM': [accuracy_score(y_test, y_pred_svm_rbf), TPR(y_test, y_pred_svm_rbf), 
                                FPR(y_test, y_pred_svm_rbf)]}
                  #'Polynomial SVM': [accuracy_score(y_test, y_pred_svm_poly), TPR(y_test, y_pred_svm_poly),
                                     #FPR(y_test, y_pred_svm_poly)]}

performance_df = pd.DataFrame(data=comparison_data, index=['Accuracy', 'TPR', 'FPR'])
performance_df
# Out:
#           Baseline  Logistic Regression  Decision Tree  Vanilla Bagging  \
# Accuracy  0.571006             0.810651       0.807692         0.804734
# TPR       0.000000             0.758621       0.779310         0.751724
# FPR       0.000000             0.150259       0.170984         0.155440
#
#           Random Forest  Linear SVM   RBF SVM
# Accuracy       0.816568    0.443787  0.573964
# TPR            0.724138    1.000000  0.006897
# FPR            0.113990    0.974093  0.000000

# %%
# importance score for random forest

pd.DataFrame({'Feature' : X_train.columns,  
              'Importance score': 100*rf_cv.best_estimator_.feature_importances_}).round(1).sort_values(
                    'Importance score', ascending=False)
# Out:
#                                      Feature  Importance score
# 48              mental_health_consequence_No              12.9
# 57                            supervisor_Yes               8.5
# 49             mental_health_consequence_Yes               7.0
# 55                             supervisor_No               5.8
# 46                           leave_Very easy               5.4
# 0                                        age               4.1
# 29                       wellness_program_No               3.1
# 38                             anonymity_Yes               2.6
# 30                      wellness_program_Yes               2.6
# 14                          tech_company_0.0               2.5
# 53                             coworkers_Yes               2.4
# 51                              coworkers_No               2.3
# 44                       leave_Somewhat easy               2.1
# 34                             seek_help_Yes               2.1
# 33                              seek_help_No               2.0
# 47           mental_health_consequence_Maybe               1.9
# 13               no_employees_More than 1000               1.9
# 17                          tech_company_Yes               1.6
# 45                      leave_Very difficult               1.6
# 54                          supervisor_Maybe               1.4
# 43                  leave_Somewhat difficult               1.4
# 5                                treatment_1               1.2
# 24                           care_options_No               1.1
# 8                           no_employees_1-5               1.1
# 2                          family_history_No               1.1
# 27               wellness_program_Don't know               1.1
# 10                       no_employees_26-100               1.0
# 36                    anonymity_I don't know               1.0
# 15                          tech_company_1.0               1.0
# 25                     care_options_Not sure               1.0
# 23                              benefits_Yes               1.0
# 12                         no_employees_6-25               1.0
# 52                    coworkers_Some of them               0.9
# 3                         family_history_Yes               0.9
# 6                               treatment_No               0.9
# 4                                treatment_0               0.8
# 26                          care_options_Yes               0.8
# 31                      seek_help_Don't know               0.7
# 40                          leave_Don't know               0.7
# 50                           coworkers_Maybe               0.7
# 35                      anonymity_Don't know               0.6
# 9                       no_employees_100-500               0.6
# 1                family_history_I don't know               0.6
# 20                               benefits_No               0.6
# 7                              treatment_Yes               0.6
# 56                   supervisor_Some of them               0.5
# 19                     benefits_I don't know               0.5
# 32                    seek_help_I don't know               0.5
# 41                        leave_I don't know               0.5
# 42          leave_Neither easy nor difficult               0.4
# 18                       benefits_Don't know               0.3
# 16                           tech_company_No               0.3
# 37                              anonymity_No               0.3
# 28             wellness_program_I don't know               0.2
# 11                     no_employees_500-1000               0.2
# 21  benefits_Not eligible for coverage / N/A               0.1
# 39                           leave_Difficult               0.1
# 22   benefits_Not eligible for coverage / NA               0.1

# %%
corr = pd.get_dummies(train).corr()[['mental_vs_physical']].sort_values('mental_vs_physical', ascending=False).iloc[1:,:]

# %%
positive_corr = corr[corr['mental_vs_physical'] > 0]
negative_corr = corr[corr['mental_vs_physical']<0]

# %%
# positive correlation bar graph

plt.figure(figsize=(8,7))
plt.barh(positive_corr.index, 100*positive_corr['mental_vs_physical'])
plt.title('Positive Correlation for variables and mental_vs_physical (scaled by 100)');
plt.show()

# %%
# negative correlation bar graph

plt.figure(figsize=(8,7))
plt.barh(negative_corr.index, abs(100*negative_corr['mental_vs_physical']))
plt.title('Absolute Value Negative Correlation for variables and mental_vs_physical (scaled by 100)');
plt.show()

# %%
from sklearn.feature_selection import SelectFromModel

sel = SelectFromModel(RandomForestClassifier(n_estimators = 100))
sel.fit(X_train, y_train)

sel.get_support()
# Out:
# array([ True, False,  True, False, False, False, False, False, False,
#        False,  True, False, False,  True,  True, False, False, False,
#        False, False, False, False, False, False,  True, False, False,
#        False, False,  True,  True, False, False,  True,  True, False,
#        False, False,  True, False, False, False, False, False,  True,
#        False,  True,  True,  True,  True, False,  True, False,  True,
#        False,  True, False,  True])

# %%
selected_feat = X_train.columns[(sel.get_support())]
selected_feat
# Out:
# Index(['age', 'family_history_No', 'no_employees_26-100',
#        'no_employees_More than 1000', 'tech_company_0.0', 'care_options_No',
#        'wellness_program_No', 'wellness_program_Yes', 'seek_help_No',
#        'seek_help_Yes', 'anonymity_Yes', 'leave_Somewhat easy',
#        'leave_Very easy', 'mental_health_consequence_Maybe',
#        'mental_health_consequence_No', 'mental_health_consequence_Yes',
#        'coworkers_No', 'coworkers_Yes', 'supervisor_No', 'supervisor_Yes'],
#       dtype='object')

# %%
Linear SVM, RBF SVM, and Polynomial SVM can bee compared with each other (see hw 2 i think)
# Out:
#   File "<ipython-input-52-b237a18b2c59>", line 1
#     Linear SVM, RBF SVM, and Polynomial SVM can bee compared with each other (see hw 2 i think)
#            ^
# SyntaxError: invalid syntax
